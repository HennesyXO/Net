# %% [markdown]
# <a href="https://colab.research.google.com/github/yustinaivanova/netology_statistics/blob/master/dz_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Домашняя работа №4

# %% [markdown]
# # Виды распределений

# %% [markdown]
# Загрузить таблицу и построить график распределений. Найти нормальное распределение.

# %%
import numpy as np
from scipy.stats import t
from scipy.stats import norm
import matplotlib.pyplot as plt
from scipy import stats
import pandas as pd
import io
import requests
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# Таблица цен на дома в Бостоне

# %% [markdown]
# Основные значения:
#
# * CRIM: This is the per capita crime rate by town
# * ZN: This is the proportion of residential land zoned for lots larger than 25,000 sq.ft.
# * INDUS: This is the proportion of non-retail business acres per town.
# * CHAS: This is the Charles River dummy variable (this is equal to 1 if tract bounds river; 0 otherwise)
# * NOX: This is the nitric oxides concentration (parts per 10 million)
# * RM: This is the average number of rooms per dwelling
# * AGE: This is the proportion of owner-occupied units built prior to 1940
# * DIS: This is the weighted distances to five Boston employment centers
# * RAD: This is the index of accessibility to radial highways
# * TAX: This is the full-value property-tax rate per 10,000 dollars
# * PTRATIO: This is the pupil-teacher ratio by town
# * B: This is calculated as 1000(Bk — 0.63)², where Bk is the proportion of people of African American descent by town
# * LSTAT: This is the percentage lower status of the population
# * MEDV: This is the median value of owner-occupied homes in 1000 dollars

# %%
import ssl
# следующая строчка подключает сертификат для защищенного соединения
ssl._create_default_https_context = ssl._create_unverified_context
url='http://yustiks.ru/dataset/housing.csv'
names = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV']
data = pd.read_csv(url,  delim_whitespace=True, names=names)
data.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %%
data.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677082   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# std     28.148861    2.105710    8.707259  168.537116    2.164946   91.294864
# min      2.900000    1.129600    1.000000  187.000000   12.600000    0.320000
# 25%     45.025000    2.100175    4.000000  279.000000   17.400000  375.377500
# 50%     77.500000    3.207450    5.000000  330.000000   19.050000  391.440000
# 75%     94.075000    5.188425   24.000000  666.000000   20.200000  396.225000
# max    100.000000   12.126500   24.000000  711.000000   22.000000  396.900000
#
#             LSTAT        MEDV
# count  506.000000  506.000000
# mean    12.653063   22.532806
# std      7.141062    9.197104
# min      1.730000    5.000000
# 25%      6.950000   17.025000
# 50%     11.360000   21.200000
# 75%     16.955000   25.000000
# max     37.970000   50.000000

# %% [markdown]
# Нарисовать частотные графики для всех значений. Можете ли вы найти следующие распределения в данных графиках?
#
#
# 1.   Нормальное
# 2.   Равномерное
# 3.   Биноминальное
# 4.   Бернулли
# 5.   Геометрическое
# 6.   Логнормальное

# %%
# частотные графики
fig, axs = plt.subplots(nrows=7, ncols=2, figsize=(10,30))
for i in range(2): 
    for j in range(7):
        sns.distplot(data.iloc[:,[j+7*i]], kde=False, ax=axs[j, i])
        axs[j,i].set_title(data.columns[j+7*i])

# %% [markdown]
# Построить матрицу корреляций для данной таблицы и выбрать максимально коррелирующий атрибут (несколько атрибутов) с ценой на дома (MEDV атрибут).

# %%
data.corr()
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734
# ZN      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# INDUS    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# CHAS    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# NOX      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# RM      -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# AGE      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# DIS     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# RAD      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# TAX      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# PTRATIO  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# B       -0.385064  0.175520 -0.356977  0.048788 -0.380051  0.128069 -0.273534
# LSTAT    0.455621 -0.412995  0.603800 -0.053929  0.590879 -0.613808  0.602339
# MEDV    -0.388305  0.360445 -0.483725  0.175260 -0.427321  0.695360 -0.376955
#
#               DIS       RAD       TAX   PTRATIO         B     LSTAT      MEDV
# CRIM    -0.379670  0.625505  0.582764  0.289946 -0.385064  0.455621 -0.388305
# ZN       0.664408 -0.311948 -0.314563 -0.391679  0.175520 -0.412995  0.360445
# INDUS   -0.708027  0.595129  0.720760  0.383248 -0.356977  0.603800 -0.483725
# CHAS    -0.099176 -0.007368 -0.035587 -0.121515  0.048788 -0.053929  0.175260
# NOX     -0.769230  0.611441  0.668023  0.188933 -0.380051  0.590879 -0.427321
# RM       0.205246 -0.209847 -0.292048 -0.355501  0.128069 -0.613808  0.695360
# AGE     -0.747881  0.456022  0.506456  0.261515 -0.273534  0.602339 -0.376955
# DIS      1.000000 -0.494588 -0.534432 -0.232471  0.291512 -0.496996  0.249929
# RAD     -0.494588  1.000000  0.910228  0.464741 -0.444413  0.488676 -0.381626
# TAX     -0.534432  0.910228  1.000000  0.460853 -0.441808  0.543993 -0.468536
# PTRATIO -0.232471  0.464741  0.460853  1.000000 -0.177383  0.374044 -0.507787
# B        0.291512 -0.444413 -0.441808 -0.177383  1.000000 -0.366087  0.333461
# LSTAT   -0.496996  0.488676  0.543993  0.374044 -0.366087  1.000000 -0.737663
# MEDV     0.249929 -0.381626 -0.468536 -0.507787  0.333461 -0.737663  1.000000

# %%
# матрица корреляции, цветная
data.corr().style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <style  type="text/css" >
#     #T_62ae888a_b52c_11ea_817a_4074e0bd88a9row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_62ae888a_b52c_11ea_817a_4074e0bd88a9row0_col1 {
#             background-color:  #88abfd;
#             color:  #000000;
#         }    #T_62ae888a_b52c_11ea_817a_4074e0bd88a9row0_col2 {
#             background-color:  #f7bca1;
#             color:  #000000;
#         }    #T_62ae888a_b52c_11ea_817a_4074e0bd88a9row0_col3 {
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }    #T_62ae888a_b52c_11ea_817a_4074e0bd88a9row0_col4 {
#             background-color:  #f7b599;
#             color:  #000000;
#         }    #T_62ae888a_b52c_11ea_817a_4074e0bd88a9row0_col5 {
#             background-color:  #8badfd;
#             color:  #000000;
#         }    #T_62ae888a_b52c_11ea_817a_4074e0bd88a9row0_col6 {
#             background-color:  #f5c2aa;
#             color:  #000000;
#         }    #T_62ae888a_b52c_11ea_817a_4074e0bd88a9row0_col7 {
#             background-color:  #82a6fb;
#             color:  #000000;
#         }    #T_62ae888a_b52c_11ea_817a_4074e0bd88a9row0_col8 {
#             background-color:  #f49a7b;
#             color:  #000000;
#         }    #T_62ae888a_b52c_11ea_817a_4074e0bd88a9row0_col9 {
#             background-color:  #f6a283;
#             color:  #000000;
#         }    #T_62ae888a_b52c_11ea_817a_4074e0bd88a9row0_col10 {
#             background-color:  #e4d9d2;
#             color:  #000000;
#         }    #T_62ae888a_b52c_11ea_817a_4074e0bd88a9row0_col11 {
#             background-color:  #465ecf;
#             color:  #f1f1f1;
#         }    #T_62ae888a_b52c_11ea_817a_4074e0bd88a9row0_col12 {
#             background-color:  #f7b194;
#             color:  #000000;
#         }    #T_62ae888a_b52c_11ea_817a_4074e0bd88a9row0_col13 {
#             background-color:  #7b9ff9;
#             color:  #000000;
#         }    #T_62ae888a_b52c_11ea_817a_4074e0bd88a9row1_col0 {
#             background-color:  #6485ec;
#             color:  #000000;
#         }    #T_62ae888a_b52c_11ea_817a_4074e0bd88a9row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_62ae888a_b52c_11ea_817a_4074e0bd88a9row1_col2 {
#             background-color:  #5a78e4;
#             color:  #000000;
#         }    #T_62ae888a_b52c_11ea_817a_4074e0bd88a9row1_col3 {
#             background-color:  #4f69d9;
#             color:  #000000;
#         }    #T_62ae888a_b52c_11ea_817a_4074e0bd88a9row1_col4 {
#             background-color:  #6788ee;
#             color:  #000000;
#         }    #T_62ae888a_b52c_11ea_817a_4074e0bd88a9row1_col5 {
#             background-color:  #edd1c2;
#             color:  #000000;
#         }    #T_62ae888a_b52c_11ea_817a_4074e0bd88a9row1_col6 {
#             background-color:  #5a78e4;
#             color:  #000000;
#         }    #T_62ae888a_b52c_11ea_817a_4074e0bd88a9row1_col7 {
#             background-color:  #ec7f63;
#             color:  #000000;
#         }    #T_62ae888a_b52c_11ea_817a_4074e0bd88a9row1_col8 {
#             background-color:  #6180e9;
#             color:  #000000;
#         }    #T_62ae888a_b52c_11ea_817a_4074e0bd88a9row1_col9 {
#             background-color:  #6788ee;
#             color:  #000000;
#         }    #T_62ae888a_b52c_11ea_817a_4074e0bd88a9row1_col10 {
#             background-color:  #516ddb;
#             color:  #000000;
#         }    #T_62ae888a_b52c_11ea_817a_4074e0bd88a9row1_col11 {
#             background-color:  #c9d7f0;
#             color:  #000000;
#         }    #T_62ae888a_b52c_11ea_817a_4074e0bd88a9row1_col12 {
#             background-color:  #7699f6;
#             color:  #000000;
#         }    #T_62ae888a_b52c_11ea_817a_4074e0bd88a9row1_col13 {
#             background-color:  #f5c2aa;
#             color:  #000000;
#         }    #T_62ae888a_b52c_11ea_817a_4074e0bd88a9row2_col0 {
#             background-color:  #edd1c2;
#             color:  #000000;
#         }    #T_62ae888a_b52c_11ea_817a_4074e0bd88a9row2_col1 {
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }    #T_62ae888a_b52c_11ea_817a_4074e0bd88a9row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_62ae888a_b52c_11ea_817a_4074e0bd88a9row2_col3 {
#             background-color:  #6f92f3;
#             color:  #000000;
#         }    #T_62ae888a_b52c_11ea_817a_4074e0bd88a9row2_col4 {
#             background-color:  #e0654f;
#             color:  #000000;
#         }    #T_62ae888a_b52c_11ea_817a_4074e0bd88a9row2_col5 {
#             background-color:  #6687ed;
#             color:  #000000;
#         }    #T_62ae888a_b52c_11ea_817a_4074e0bd88a9row2_col6 {
#             background-color:  #ee8669;
#             color:  #000000;
#         }    #T_62ae888a_b52c_11ea_817a_4074e0bd88a9row2_col7 {
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }    #T_62ae888a_b52c_11ea_817a_4074e0bd88a9row2_col8 {
#             background-color:  #f6a283;
#             color:  #000000;
#         }    #T_62ae888a_b52c_11ea_817a_4074e0bd88a9row2_col9 {
#             background-color:  #ea7b60;
#             color:  #000000;
#         }    #T_62ae888a_b52c_11ea_817a_4074e0bd88a9row2_col10 {
#             background-color:  #f1cdba;
#             color:  #000000;
#         }    #T_62ae888a_b52c_11ea_817a_4074e0bd88a9row2_col11 {
#             background-color:  #4c66d6;
#             color:  #000000;
#         }    #T_62ae888a_b52c_11ea_817a_4074e0bd88a9row2_col12 {
#             background-color:  #f29072;
#             color:  #000000;
#         }    #T_62ae888a_b52c_11ea_817a_4074e0bd88a9row2_col13 {
#             background-color:  #688aef;
#             color:  #000000;
#         }    #T_62ae888a_b52c_11ea_817a_4074e0bd88a9row3_col0 {
#             background-color:  #89acfd;
#             color:  #000000;
#         }    #T_62ae888a_b52c_11ea_817a_4074e0bd88a9row3_col1 {
#             background-color:  #aac7fd;
#             color:  #000000;
#         }    #T_62ae888a_b52c_11ea_817a_4074e0bd88a9row3_col2 {
#             background-color:  #cfdaea;
#             color:  #000000;
#         }    #T_62ae888a_b52c_11ea_817a_4074e0bd88a9row3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_62ae888a_b52c_11ea_817a_4074e0bd88a9row3_col4 {
#             background-color:  #d9dce1;
#             color:  #000000;
#         }    #T_62ae888a_b52c_11ea_817a_4074e0bd88a9row3_col5 {
#             background-color:  #cbd8ee;
#             color:  #000000;
#         }    #T_62ae888a_b52c_11ea_817a_4074e0bd88a9row3_col6 {
#             background-color:  #d7dce3;
#             color:  #000000;
#         }    #T_62ae888a_b52c_11ea_817a_4074e0bd88a9row3_col7 {
#             background-color:  #b9d0f9;
#             color:  #000000;
#         }    #T_62ae888a_b52c_11ea_817a_4074e0bd88a9row3_col8 {
#             background-color:  #a7c5fe;
#             color:  #000000;
#         }    #T_62ae888a_b52c_11ea_817a_4074e0bd88a9row3_col9 {
#             background-color:  #a7c5fe;
#             color:  #000000;
#         }    #T_62ae888a_b52c_11ea_817a_4074e0bd88a9row3_col10 {
#             background-color:  #8fb1fe;
#             color:  #000000;
#         }    #T_62ae888a_b52c_11ea_817a_4074e0bd88a9row3_col11 {
#             background-color:  #adc9fd;
#             color:  #000000;
#         }    #T_62ae888a_b52c_11ea_817a_4074e0bd88a9row3_col12 {
#             background-color:  #bed2f6;
#             color:  #000000;
#         }    #T_62ae888a_b52c_11ea_817a_4074e0bd88a9row3_col13 {
#             background-color:  #e3d9d3;
#             color:  #000000;
#         }    #T_62ae888a_b52c_11ea_817a_4074e0bd88a9row4_col0 {
#             background-color:  #efcebd;
#             color:  #000000;
#         }    #T_62ae888a_b52c_11ea_817a_4074e0bd88a9row4_col1 {
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }    #T_62ae888a_b52c_11ea_817a_4074e0bd88a9row4_col2 {
#             background-color:  #e16751;
#             color:  #000000;
#         }    #T_62ae888a_b52c_11ea_817a_4074e0bd88a9row4_col3 {
#             background-color:  #779af7;
#             colo

# %%
mdev_corr = data.corr()['MEDV'].sort_values(ascending=False)
print('Максимальная корреляция с ценой дома (MDEV) у атрибутов: ')
print(mdev_corr[(mdev_corr != 1) & ((mdev_corr > 0.6) | (mdev_corr < -0.6))])
# Out:
# Максимальная корреляция с ценой дома (MDEV) у атрибутов:
# RM       0.695360
# LSTAT   -0.737663
# Name: MEDV, dtype: float64

# %% [markdown]
# Написать **линейную регрессию** на два атрибута. Допустим, мы хотим предсказать цену дома (MEDV) в Бостоне, зная что цена на дом имеет линейную зависимость с атрибутом LSTAT.

# %% [markdown]
# 1.   Разделить данные на 80% тренировочных, 20% тестовых
# 2.   Составить модель линейной регрессии
# 3.   Посчитать ошибку модели на тестовых данных
# 4.   Сделать точечный график данных и полученной прямой линейной регрессии

# %%
# линейная регрессия MDEV & LSTAT
# 0 подготовка данных 
medv = np.array(data['MEDV']).reshape(-1,1)
lstat = np.array(data['LSTAT']).reshape(-1,1)

# 1. разделение данных на 80% тренировочных и 20% тестовых 
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(
    lstat,
    medv,
    test_size = 0.2
)

# 2. Модель
from sklearn.linear_model import LinearRegression
model_medv_lstat = LinearRegression()
model_medv_lstat.fit(x_train, y_train)

# 3. Ошибка модели на тестовых данных
from sklearn.metrics import mean_squared_error, mean_absolute_error
predicted_y = model_medv_lstat.predict(x_test)
print(mean_squared_error(predicted_y, y_test))
print(mean_absolute_error(predicted_y, y_test))
# Out:
# 30.46242246752585
# 4.379780511337933

# %%
# 4 график
plt.xlabel('LSTAT')
plt.ylabel('MEDV')
plt.title('Линейная регрессия от одной переменной')
# Построим прямую для регрессии
# Создадим 100 точек для предсказаний
x = np.linspace(0, 50, 100)
# Посчитаем предсказанные значения
y = model_medv_lstat.coef_*x + model_medv_lstat.intercept_
y = np.transpose(y)
plt.plot(x,y)
plt.plot(x_train, y_train, 'r.')
plt.plot(x_test, y_test, 'go')
plt.xlim(0, 40)
plt.ylim(-10, 60)
plt.legend([ 'Прямая линейной регрессии','Тренировочные данные','Тестовые данные'])
#plt.show()

# %%
# линейная регрессия MDEV & RM
# 0 подготовка данных 
medv = np.array(data['MEDV']).reshape(-1,1)
rm = np.array(data['RM']).reshape(-1,1)


# 1. разделение данных на 80% тренировочных и 20% тестовых 
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(    
    rm,
    medv,
    test_size = 0.2
)

# 2. Модель
from sklearn.linear_model import LinearRegression
model_medv_rm = LinearRegression()
model_medv_rm.fit(x_train, y_train)

# 3. ошибка модели на тестовых данных 
from sklearn.metrics import mean_squared_error, mean_absolute_error
predicted_y = model_medv_rm.predict(x_test)
print(mean_squared_error(predicted_y, y_test))
print(mean_absolute_error(predicted_y, y_test))

# 4 график
plt.xlabel('RM')
plt.ylabel('MEDV')
plt.title('Линейная регрессия от одной переменной')
# Построим прямую для регрессии
# Создадим 100 точек для предсказаний
x = np.linspace(0, 50, 100)
# Посчитаем предсказанные значения
y = model_medv_rm.coef_*x + model_medv_rm.intercept_
y = np.transpose(y)
plt.plot(x,y)
plt.plot(x_train, y_train, 'r.')
plt.plot(x_test, y_test, 'go')
plt.xlim(0, 10)
plt.ylim(-10, 60)
plt.legend(['Прямая линейной регрессии', 'Тренировочные данные', 'Тестовые данные'])
plt.show()
# Out:
# 54.58058979523132
# 5.272761463777005

# %% [markdown]
# Загрузить таблицу Happiness report. Посчитать матрицу ковариаций попарно.

# %%
url="http://yustiks.ru/dataset/world-happiness-report-2019.csv"
data=pd.read_csv(url)
data.head()
# Out:
#   Country (region)  Ladder  SD of Ladder  Positive affect  Negative affect  \
# 0          Finland       1             4             41.0             10.0
# 1          Denmark       2            13             24.0             26.0
# 2           Norway       3             8             16.0             29.0
# 3          Iceland       4             9              3.0              3.0
# 4      Netherlands       5             1             12.0             25.0
#
#    Social support  Freedom  Corruption  Generosity  Log of GDP\nper capita  \
# 0             2.0      5.0         4.0        47.0                    22.0
# 1             4.0      6.0         3.0        22.0                    14.0
# 2             3.0      3.0         8.0        11.0                     7.0
# 3             1.0      7.0        45.0         3.0                    15.0
# 4            15.0     19.0        12.0         7.0                    12.0
#
#    Healthy life\nexpectancy
# 0                      27.0
# 1                      23.0
# 2                      12.0
# 3                      13.0
# 4                      18.0

# %% [markdown]
# Сколько в данной таблице отсутствующих значений? Написать ответ. Если есть отсутствующие значения в выборке country, убрать (drop).

# %%
print('Количество отсутствующих значений по столбцам: ')
print(data.isnull().sum())
data.dropna(inplace=True)
# Out:
# Количество отсутствующих значений по столбцам:
# Country (region)            0
# Ladder                      0
# SD of Ladder                0
# Positive affect             0
# Negative affect             0
# Social support              0
# Freedom                     0
# Corruption                  0
# Generosity                  0
# Log of GDP\nper capita      0
# Healthy life\nexpectancy    0
# dtype: int64

# %% [markdown]
# Сколько стран в выборке? Написать ответ.

# %%
print('В выборке', data['Country (region)'].nunique(), 'стран.')
# Out:
# В выборке 140 стран.

# %% [markdown]
# Построить матрицу корреляций для таблицы. Какие можно сделать выводы?

# %%
data.corr().style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <style  type="text/css" >
#     #T_c7b0c91e_b543_11ea_a325_4074e0bd88a9row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_c7b0c91e_b543_11ea_a325_4074e0bd88a9row0_col1 {
#             background-color:  #e0dbd8;
#             color:  #000000;
#         }    #T_c7b0c91e_b543_11ea_a325_4074e0bd88a9row0_col2 {
#             background-color:  #d3dbe7;
#             color:  #000000;
#         }    #T_c7b0c91e_b543_11ea_a325_4074e0bd88a9row0_col3 {
#             background-color:  #cedaeb;
#             color:  #000000;
#         }    #T_c7b0c91e_b543_11ea_a325_4074e0bd88a9row0_col4 {
#             background-color:  #ed8366;
#             color:  #000000;
#         }    #T_c7b0c91e_b543_11ea_a325_4074e0bd88a9row0_col5 {
#             background-color:  #bfd3f6;
#             color:  #000000;
#         }    #T_c7b0c91e_b543_11ea_a325_4074e0bd88a9row0_col6 {
#             background-color:  #5572df;
#             color:  #000000;
#         }    #T_c7b0c91e_b543_11ea_a325_4074e0bd88a9row0_col7 {
#             background-color:  #98b9ff;
#             color:  #000000;
#         }    #T_c7b0c91e_b543_11ea_a325_4074e0bd88a9row0_col8 {
#             background-color:  #f18d6f;
#             color:  #000000;
#         }    #T_c7b0c91e_b543_11ea_a325_4074e0bd88a9row0_col9 {
#             background-color:  #ee8669;
#             color:  #000000;
#         }    #T_c7b0c91e_b543_11ea_a325_4074e0bd88a9row1_col0 {
#             background-color:  #c9d7f0;
#             color:  #000000;
#         }    #T_c7b0c91e_b543_11ea_a325_4074e0bd88a9row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_c7b0c91e_b543_11ea_a325_4074e0bd88a9row1_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_c7b0c91e_b543_11ea_a325_4074e0bd88a9row1_col3 {
#             background-color:  #ebd3c6;
#             color:  #000000;
#         }    #T_c7b0c91e_b543_11ea_a325_4074e0bd88a9row1_col4 {
#             background-color:  #e4d9d2;
#             color:  #000000;
#         }    #T_c7b0c91e_b543_11ea_a325_4074e0bd88a9row1_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_c7b0c91e_b543_11ea_a325_4074e0bd88a9row1_col6 {
#             background-color:  #6180e9;
#             color:  #000000;
#         }    #T_c7b0c91e_b543_11ea_a325_4074e0bd88a9row1_col7 {
#             background-color:  #688aef;
#             color:  #000000;
#         }    #T_c7b0c91e_b543_11ea_a325_4074e0bd88a9row1_col8 {
#             background-color:  #f0cdbb;
#             color:  #000000;
#         }    #T_c7b0c91e_b543_11ea_a325_4074e0bd88a9row1_col9 {
#             background-color:  #edd1c2;
#             color:  #000000;
#         }    #T_c7b0c91e_b543_11ea_a325_4074e0bd88a9row2_col0 {
#             background-color:  #b6cefa;
#             color:  #000000;
#         }    #T_c7b0c91e_b543_11ea_a325_4074e0bd88a9row2_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_c7b0c91e_b543_11ea_a325_4074e0bd88a9row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_c7b0c91e_b543_11ea_a325_4074e0bd88a9row2_col3 {
#             background-color:  #82a6fb;
#             color:  #000000;
#         }    #T_c7b0c91e_b543_11ea_a325_4074e0bd88a9row2_col4 {
#             background-color:  #aac7fd;
#             color:  #000000;
#         }    #T_c7b0c91e_b543_11ea_a325_4074e0bd88a9row2_col5 {
#             background-color:  #f1ccb8;
#             color:  #000000;
#         }    #T_c7b0c91e_b543_11ea_a325_4074e0bd88a9row2_col6 {
#             background-color:  #5673e0;
#             color:  #000000;
#         }    #T_c7b0c91e_b543_11ea_a325_4074e0bd88a9row2_col7 {
#             background-color:  #779af7;
#             color:  #000000;
#         }    #T_c7b0c91e_b543_11ea_a325_4074e0bd88a9row2_col8 {
#             background-color:  #6b8df0;
#             color:  #000000;
#         }    #T_c7b0c91e_b543_11ea_a325_4074e0bd88a9row2_col9 {
#             background-color:  #84a7fc;
#             color:  #000000;
#         }    #T_c7b0c91e_b543_11ea_a325_4074e0bd88a9row3_col0 {
#             background-color:  #c3d5f4;
#             color:  #000000;
#         }    #T_c7b0c91e_b543_11ea_a325_4074e0bd88a9row3_col1 {
#             background-color:  #f1ccb8;
#             color:  #000000;
#         }    #T_c7b0c91e_b543_11ea_a325_4074e0bd88a9row3_col2 {
#             background-color:  #9abbff;
#             color:  #000000;
#         }    #T_c7b0c91e_b543_11ea_a325_4074e0bd88a9row3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_c7b0c91e_b543_11ea_a325_4074e0bd88a9row3_col4 {
#             background-color:  #f3c7b1;
#             color:  #000000;
#         }    #T_c7b0c91e_b543_11ea_a325_4074e0bd88a9row3_col5 {
#             background-color:  #82a6fb;
#             color:  #000000;
#         }    #T_c7b0c91e_b543_11ea_a325_4074e0bd88a9row3_col6 {
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }    #T_c7b0c91e_b543_11ea_a325_4074e0bd88a9row3_col7 {
#             background-color:  #5875e1;
#             color:  #000000;
#         }    #T_c7b0c91e_b543_11ea_a325_4074e0bd88a9row3_col8 {
#             background-color:  #d4dbe6;
#             color:  #000000;
#         }    #T_c7b0c91e_b543_11ea_a325_4074e0bd88a9row3_col9 {
#             background-color:  #c6d6f1;
#             color:  #000000;
#         }    #T_c7b0c91e_b543_11ea_a325_4074e0bd88a9row4_col0 {
#             background-color:  #f08a6c;
#             color:  #000000;
#         }    #T_c7b0c91e_b543_11ea_a325_4074e0bd88a9row4_col1 {
#             background-color:  #ebd3c6;
#             color:  #000000;
#         }    #T_c7b0c91e_b543_11ea_a325_4074e0bd88a9row4_col2 {
#             background-color:  #b9d0f9;
#             color:  #000000;
#         }    #T_c7b0c91e_b543_11ea_a325_4074e0bd88a9row4_col3 {
#             background-color:  #f2c9b4;
#             color:  #000000;
#         }    #T_c7b0c91e_b543_11ea_a325_4074e0bd88a9row4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_c7b0c91e_b543_11ea_a325_4074e0bd88a9row4_col5 {
#             background-color:  #9fbfff;
#             color:  #000000;
#         }    #T_c7b0c91e_b543_11ea_a325_4074e0bd88a9row4_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_c7b0c91e_b543_11ea_a325_4074e0bd88a9row4_col7 {
#             background-color:  #86a9fc;
#             color:  #000000;
#         }    #T_c7b0c91e_b543_11ea_a325_4074e0bd88a9row4_col8 {
#             background-color:  #f39778;
#             color:  #000000;
#         }    #T_c7b0c91e_b543_11ea_a325_4074e0bd88a9row4_col9 {
#             background-color:  #f7a889;
#             color:  #000000;
#         }    #T_c7b0c91e_b543_11ea_a325_4074e0bd88a9row5_col0 {
#             background-color:  #c5d6f2;
#             color:  #000000;
#         }    #T_c7b0c91e_b543_11ea_a325_4074e0bd88a9row5_col1 {
#             background-color:  #7396f5;
#             color:  #000000;
#         }    #T_c7b0c91e_b543_11ea_a325_4074e0bd88a9row5_col2 {
#             background-color:  #f7b89c;
#             color:  #000000;
#         }    #T_c7b0c91e_b543_11ea_a325_4074e0bd88a9row5_col3 {
#             background-color:  #9ebeff;
#             color:  #000000;
#         }    #T_c7b0c91e_b543_11ea_a325_4074e0bd88a9row5_col4 {
#             background-color:  #bcd2f7;
#             color:  #000000;
#         }    #T_c7b0c91e_b543_11ea_a325_4074e0bd88a9row5_col5 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_c7b0c91e_b543_11ea_a325_4074e0bd88a9row5_col6 {
#             background-color:  #9fbfff;
#             color:  #000000;
#         }    #T_c7b0c91e_b543_11ea_a325_4074e0bd88a9row5_col7 {
#             background-color:  #9fbfff;
#             color:  #000000;
#         }    #T_c7b0c91e_b543_11ea_a325_4074e0bd88a9row5_col8 {
#             background-color:  #8badfd;
#             color:  #000000;
#         }    #T_c7b0c91e_b543_11ea_a325_4074e0bd88a9row5_col9 {
#             background-color:  #a6c4fe;
#             color:  #000000;

# %%
cor = data.corr()
print('В выбоке есть', cor[(cor > 0.7) & (cor != 1.)].count().sum()/2,'пар с коэффициентом корреляции более 0.7')
# Out:
# В выбоке есть 6.0 пар с коэффициентом корреляции более 0.7

# %% [markdown]
# # Дискретное распределение случайной величины

# %% [markdown]
# Напишите код для моделирования 10 подбрасываний игрального кубика. Начертите диаграму histogram. Какое это распределение?

# %%
# моделирование 10 подбрасываний
cube = np.random.randint(1, high=6+1, size=10)

ax = plt.hist(cube)
plt.xlabel('Сторона игрального кубика')
plt.title('Плотности вероятности выпадания стороны')
# Out:
# Text(0.5, 1.0, 'Плотности вероятности выпадания стороны')

# %%
ax = plt.hist(np.random.randint(1, high=6+1, size=10))
plt.xlabel('Сторона игрального кубика')
plt.title('Плотности вероятности выпадания стороны')
# Out:
# Text(0.5, 1.0, 'Плотности вероятности выпадания стороны')

# %% [markdown]
# Для 10 подбрасываний сложно судить - распределение может быть разным. Для большего количества подбрасываний видно равномерное распределение:

# %%
# моделирование 10 тыс. подбрасываний
cube = np.random.randint(1, high=6+1, size=10000)

ax = plt.hist(cube)
plt.xlabel('Сторона игрального кубика')
plt.title('Плотности вероятности выпадания стороны')
# Out:
# Text(0.5, 1.0, 'Плотности вероятности выпадания стороны')

# %% [markdown]
# Смоделируйте 1000 раз сумму по 100 подбрасываний. Начертите диаграму histogram. Почему график изменился? Почему можно применить центральную предельную теорему?

# %%
sum_cubes = []
for _ in range(1000):
    sum_cubes.append(sum(np.random.randint(1, high=6+1, size=100)))

ax = plt.hist(sum_cubes)
plt.xlabel('Сторона 100 подбрасываний игрального кубика')
plt.title('Плотности вероятности выпадания стороны')
# Out:
# Text(0.5, 1.0, 'Плотности вероятности выпадания стороны')

# %% [markdown]
# Сами суммы большого количества (100) случайных ввеличин одного масштаба не зависят друг от друга. И поэтому имеют нормальное распределение близкого масштаба - в соответствии с центральной предельной теоремой.
